# %% [markdown]
# <a href="https://colab.research.google.com/github/OladotunOlanipekun/Discrete-Mathematics/blob/main/OlanipekunOladotun_CPSMA_3913_01_Module5_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 5: CPSMA 3913 Dr. Lynam's Discrete Mathematics utilizing [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics github repository
#
# ## Project Module 5: Structures
#
# ### Oladotun Olanipekun 271479

# %% [markdown]
# ## 1.) Create a graph, directed graph, weighted graph, or tree.
#
# I am going to choose to create a family tree.

# %% [markdown]
# ## Part A: Create a structure with at least 5 vertices and 5 edges
#
# Because I was young when I met most of my family memebers when I went to nigeria it is hard for me to compleatly remember the names and exactly how many people are in my family but I will try my best with this. I know more of my moms side because she has two sisters that live in america. One we call big mommy because she is the oldest sibling in my moms family and the other is auntie bose. They all came to america together and I grew up around them and with their children

# %% [markdown]
# ## Part B: Visualize your structure using graphviz package.

# %%
import graphviz

olanipekun = graphviz.Graph(comment='olanipekun family')
olanipekun.node('1', 'Dads parents')
olanipekun.node('2', ' Moms parents')
olanipekun.node('3', 'Dad and Mom')
olanipekun.node('4', 'son 1')
olanipekun.node('5', 'son 2')
olanipekun.node('6', 'daughter 1')
olanipekun.node('7', 'son 1')
olanipekun.node('8', 'Big mommy')
olanipekun.node('9', 'Aunti Bose')
olanipekun.node('A', 'Olamide',)
olanipekun.node('B', 'Oladotun')
olanipekun.node('C', 'Oluwapelumi')



olanipekun.edges(['14','15','16','13','23','27','28','29'])

olanipekun.edges(['3A', '3B','3C'])
olanipekun

# %%
import graphviz
olanipekun = graphviz.Digraph('Big mommy family')

olanipekun.edge('Big mommy','Durodaye','Married')
olanipekun.edge('Durodaye','Ayo','son')
olanipekun.edge('Durodaye','Segun','son')
olanipekun.edge('Durodaye','Ife','son')

olanipekun

# %%
import graphviz
olanipekun = graphviz.Digraph('Aunti Bose family')

olanipekun.edge('Aunti Bose','Folana','Married')
olanipekun.edge('Folana','Ayomide','son')
olanipekun.edge('Folana','Fumilayo','daughter')

olanipekun

# %% [markdown]
# The kids from Big mommy and from Aunti Bose would be me and my brothers cosins

# %%
import graphviz
olanipekun = graphviz.Digraph('Olamide')

olanipekun.edge('Olamide','Oladotun','brother')
olanipekun.edge('Olamide','Oluwapelumi','brother')
olanipekun.edge('Olamide','Fumilayo','cousin')
olanipekun.edge('Olamide','Ayomide','cousin')
olanipekun.edge('Olamide','Ayo','cousin')
olanipekun.edge('Olamide','Segun','cousin')
olanipekun.edge('Olamide','Ife','cousin')

olanipekun

# %%
olanipekun = graphviz.Digraph('Olanipekun')

olanipekun.edge('Oladotun','Olamide','brother')
olanipekun.edge('Oladotun','Oluwapelumi','brother')
olanipekun.edge('Oladotun','Fumilayo','cousin')
olanipekun.edge('Oladotun','Ayomide','cousin')
olanipekun.edge('Oladotun','Ayo','cousin')
olanipekun.edge('Oladotun','Segun','cousin')
olanipekun.edge('Oladotun','Ife','cousin')

olanipekun

# %%
olanipekun = graphviz.Digraph('Oluwapelumi')

olanipekun.edge('Oluwapelumi','Oladotun','brother')
olanipekun.edge('Oluwapelumi','Olamide','brother')
olanipekun.edge('Oluwapelumi','Fumilayo','cousin')
olanipekun.edge('Oluwapelumi','Ayomide','cousin')
olanipekun.edge('Oluwapelumi','Ayo','cousin')
olanipekun.edge('Oluwapelumi','Segun','cousin')
olanipekun.edge('Oluwapelumi','Ife','cousin')

olanipekun

# %% [markdown]
# ## Part C: Describe a path in your structure.
# A path that I have is from $Moms Parents$ to $Segun$. If goes from $Moms Parents$ to $Big Mommy$, $Big Mommy$ to $Durodaye$, $Durodaye$ to $Segun$.
#
# This can be seen if you look at the extended part, not just the first one

# %% [markdown]
# ##Part D: Describe the degree of a vertex.
#
# The degree of the vertex $Dad and Mom$ is 5 since it has five edges conected to it

# %% [markdown]
# ## Part E: Describe a cycle in your structure if it exists. If a cycle does not exist, explain how you know.
#
# I do not have a cycle in my structure. If I had a cycle, I would have a path that started and ended at the same structure. I might have added some extra stuff that wernt needed but I decided afterwards to add in the family outside of my parents and brothers that I do know of and grew up with all my life
