# %% [markdown]
# <a href="https://colab.research.google.com/github/OladotunOlanipekun/Discrete-Mathematics/blob/main/olanipekunoladotun_cpsma3913_projectpart_4_counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3913 Dr. Lynam's Discrete Mathematics
#
# ## Project Module 4: Counting
#
# ### Oladotun Olanipekun 271479

# %%
import math
from sympy import *
x = symbols('x')

# %% [markdown]
# Which anime should I watch next

# %%
possibleChoices = ['OnePiece','Naruto','FullMetal','MobPsycho','DemonSlayer','DragonBall','CodeGeass','DeathNote']

# %% [markdown]
# ## 1 Counting

# %% [markdown]
# (a)
#
# this is a permutation with replacement
# i have 10 events each event there are 8 possible outcomes because reputation is allowed $8^{10}$
#
#
# $$ 8*8*8\dots *8 = 8^{10} $$

# %%
8**10
# Out:
# 1073741824

# %% [markdown]
# (b)
#
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$

# %%
math.factorial(17)/(math.factorial(10)*math.factorial(7))
# Out:
# 19448.0

# %% [markdown]
# (c)

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(possibleChoices,10)))
# Out:
# [('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'Naruto'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'FullMetal'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'MobPsycho'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'DemonSlayer'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'DragonBall'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'CodeGeass'), ('OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'OnePiece', 'DeathNote'), ('OnePiece', '
# ...

# %%
len(list(combinations_with_replacement(possibleChoices,10)))
# Out:
# 19448

# %% [markdown]
# ## Now without replacement

# %%
print(math.factorial(8))
# Out:
# 40320

# %% [markdown]
# If the order matters

# %%
from itertools import permutations
print(list(permutations(possibleChoices,8)))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# when order dosent matter

# %%
math.factorial(8)/(math.factorial(0)*math.factorial(8))
# Out:
# 1.0

# %%
from itertools import combinations
print(list(combinations(possibleChoices,8)))
# Out:
# [('OnePiece', 'Naruto', 'FullMetal', 'MobPsycho', 'DemonSlayer', 'DragonBall', 'CodeGeass', 'DeathNote')]

# %% [markdown]
# (d)
#
# Coeffiecent in the 5th order of (x-3)^9 is 126.
#
# (9!)/(4!*(9-4!)) = 126
